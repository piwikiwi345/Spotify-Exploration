# %% [markdown]
# # Getting Access Token

# %%
import requests
import base64
from requests import post
from requests import get
import json
import pprint 
import pandas as pd
import spotify_api_data_retrieval as api

# %%
client_id = "3f610174211649e6930e17f17645f3dd"
client_secret = "dfb8a88954ed405ca67a62d0837fd82f"

token = api.get_token(client_id, client_secret)
# Out:
# {"access_token": "BQDZ6b4FiSTc5vra_tM5ORLWA8imrWK9YajeNdavEA1jjlSDirxXjNDx1Le6ssFI3PVv9n518E7NnLBM6ogZ3y1NWyyWua6i2XTFA_yVtmo9TOwTv20", "token_type": "Bearer", "expires_in": 3600}

# %%
top_songs_usa= api.get_playlist(token, '37i9dQZEVXbLp5XoPON0wI?si=f8e98d0c030c4551')
pprint.pprint(top_songs_usa)
# Out:
# {'collaborative': False,
#  'description': 'Your weekly update of the most played tracks right now - USA.',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZEVXbLp5XoPON0wI'},
#  'followers': {'href': None, 'total': 209648},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZEVXbLp5XoPON0wI',
#  'id': '37i9dQZEVXbLp5XoPON0wI',
#  'images': [{'height': None,
#              'url': 'https://charts-images.scdn.co/assets/locale_en/regional/weekly/region_us_large.jpg',
#              'width': None}],
#  'name': 'Top Songs - USA',
#  'owner': {'display_name': 'Spotify',
#            'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#            'href': 'https://api.spotify.com/v1/users/spotify',
#            'id': 'spotify',
#            'type': 'user',
#            'uri': 'spotify:user:spotify'},
#  'primary_color': None,
#  'public': False,
#  'snapshot_id': 'NzQzMDUzODAwLDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDAwMDY1NmU=',
# ...

# %%
print(top_songs_usa['name'])
# Out:
# Top Songs - USA

# %%
test = ['37i9dQZEVXbLp5XoPON0wI?si=f8e98d0c030c4551','37i9dQZEVXbKPTKrnFPD0G?si=6e29b8aff7ad4e25']

# %%
testicle = api.compile_playlists(token, test)

# %%
print(testicle.keys())
# Out:
# dict_keys(['Top Songs - USA', 'Top Songs - Argentina'])
